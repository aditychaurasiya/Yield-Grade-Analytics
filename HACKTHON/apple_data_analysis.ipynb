# %% [markdown]
# # Apple Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"/content/raw_dataset (1).csv")

# %%
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# ...

# %%
df = df.drop_duplicates()
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         4000 non-null   float64
#  1   Weight       4000 non-null   float64
#  2   Sweetness    4000 non-null   float64
#  3   Crunchiness  4000 non-null   float64
#  4   Juiciness    4000 non-null   float64
#  5   Ripeness     4000 non-null   float64
#  6   Acidity      4000 non-null   object
#  7   Quality      4000 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 281.2+ KB

# %%
df.shape
# Out:
# (4000, 8)

# %%
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# ...

# %%
quality_mapping = {'good': 1, 'bad': 0}

df['Quality'] = df['Quality'].map(quality_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         4000 non-null   float64
#  1   Weight       4000 non-null   float64
#  2   Sweetness    4000 non-null   float64
#  3   Crunchiness  4000 non-null   float64
#  4   Juiciness    4000 non-null   float64
#  5   Ripeness     4000 non-null   float64
#  6   Acidity      4000 non-null   object
#  7   Quality      4000 non-null   int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 281.2+ KB

# %%
df['Acidity'] = df['Acidity'].astype(float)
df['Quality'] = df['Quality'].astype(bool)
df
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.491590     True
# 1    -0.722809     True
# 2     2.621636    False
# 3     0.790723     True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         4000 non-null   float64
#  1   Weight       4000 non-null   float64
#  2   Sweetness    4000 non-null   float64
#  3   Crunchiness  4000 non-null   float64
#  4   Juiciness    4000 non-null   float64
#  5   Ripeness     4000 non-null   float64
#  6   Acidity      4000 non-null   float64
#  7   Quality      4000 non-null   bool
# dtypes: bool(1), float64(7)
# memory usage: 253.9 KB

# %%
df.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840 -0.491590
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530 -0.722809
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033  2.621636
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761  0.790723
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849  0.501984
#
#    Quality
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True

# %%
list(df.columns)
# Out:
# ['Size',
#  'Weight',
#  'Sweetness',
#  'Crunchiness',
#  'Juiciness',
#  'Ripeness',
#  'Acidity',
#  'Quality']

# %%
columns_list = list(df.columns)

# %%
sns.set_palette("Paired")
custom_palette = sns.color_palette("Dark2", 20)

# %%
# EDA

plt.figure(figsize = (12, 8))
plt.figure(figsize=(16, 8))
sns.boxplot(data=df[columns_list], palette=custom_palette[:len(columns_list)],fill = False)
plt.title("Distribution of Attributes")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Removing Outliers

# %%
df.describe()
# Out:
#               Size       Weight    Sweetness  Crunchiness    Juiciness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean     -0.503015    -0.989547    -0.470479     0.985478     0.512118
# std       1.928059     1.602507     1.943441     1.402757     1.930286
# min      -7.151703    -7.149848    -6.894485    -6.055058    -5.961897
# 25%      -1.816765    -2.011770    -1.738425     0.062764    -0.801286
# 50%      -0.513703    -0.984736    -0.504758     0.998249     0.534219
# 75%       0.805526     0.030976     0.801922     1.894234     1.835976
# max       6.406367     5.790714     6.374916     7.619852     7.364403
#
#           Ripeness      Acidity
# count  4000.000000  4000.000000
# mean      0.498277     0.076877
# std       1.874427     2.110270
# min      -5.864599    -7.010538
# 25%      -0.771677    -1.377424
# 50%       0.503445     0.022609
# 75%       1.766212     1.510493
# max       7.237837     7.404736

# %%
input_data = df.copy()

# %%
columns_list = list(input_data.columns)

# %%
columns_list
# Out:
# ['Size',
#  'Weight',
#  'Sweetness',
#  'Crunchiness',
#  'Juiciness',
#  'Ripeness',
#  'Acidity',
#  'Quality']

# %%
df['Quality'].dtype
# Out:
# dtype('bool')

# %%
def remove_outliers(dataframe):
    result = dataframe.copy()
    columns_list = list(result.columns)
    for column in columns_list:
        if result[column].dtype in [int, float]:
            q1 = result[column].quantile(0.25)
            q3 = result[column].quantile(0.75)

            iqr = q3 - q1
            lower_fence = q1 - iqr*1.5
            upper_fence = q3 + iqr*1.5
            result = result[(result[column] >= lower_fence) &
                                    (result[column] <= upper_fence)]

    # Reset index after removing outliers
    result.reset_index(drop=True, inplace=True)
    return result

# %%
df=remove_outliers(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786 entries, 0 to 3785
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         3786 non-null   float64
#  1   Weight       3786 non-null   float64
#  2   Sweetness    3786 non-null   float64
#  3   Crunchiness  3786 non-null   float64
#  4   Juiciness    3786 non-null   float64
#  5   Ripeness     3786 non-null   float64
#  6   Acidity      3786 non-null   float64
#  7   Quality      3786 non-null   bool
# dtypes: bool(1), float64(7)
# memory usage: 210.9 KB

# %%
df['Acidity'] = df['Acidity'].astype(float)

# %%
df_good = df[df['Quality']==True]

# %%
df_good
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 3     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5     1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 6    -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# ...        ...       ...        ...          ...        ...       ...
# 3778  1.764253 -2.079695  -0.083383    -0.086724  -1.703385  3.840101
# 3780  1.482508 -2.581181  -0.306888     1.527877   1.056361  2.560829
# 3782 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3784 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3785  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.722809     True
# 2     0.790723     True
# 3     0.501984     True
# 5     2.414171     True
# ...

# %%
df_bad = df[df['Quality']==False]

# %%
df_bad
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 1    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 4    -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 7    -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 8    -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 9    -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# ...        ...       ...        ...          ...        ...       ...
# 3775 -2.282625 -0.225517  -1.698524     0.936855  -1.385481  3.249894
# 3776 -1.396794 -0.599596  -1.931104     1.815668   1.670732  1.614027
# 3779  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3781  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3783 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
#
#        Acidity  Quality
# 1     2.621636    False
# 4    -2.981523    False
# 7    -4.871905    False
# 8     2.185608    False
# ...

# %%
# @title Crunchiness

from matplotlib import pyplot as plt
df_good['Crunchiness'].plot(kind='hist', bins=20, title='Good Apple Crunchiness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Sweetness

from matplotlib import pyplot as plt
df_good['Sweetness'].plot(kind='hist', bins=20, title='Good Apple Sweetness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # finding Apple on Sweeter side are  good

# %%
# @title Weight

from matplotlib import pyplot as plt
df_good['Weight'].plot(kind='hist', bins=20, title='Good Weight')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Weight

from matplotlib import pyplot as plt
df_bad['Weight'].plot(kind='hist', bins=20, title='Bad Weight')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# small weight apple are bad

# %%
# @title Size

from matplotlib import pyplot as plt
df_good['Size'].plot(kind='hist', bins=20, title='Good Size')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Size

from matplotlib import pyplot as plt
df_bad['Size'].plot(kind='hist', bins=20, title='Bad Size')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#medium size APPLE  are generally good Quality

# %%
# @title Crunchiness

from matplotlib import pyplot as plt
df_bad['Crunchiness'].plot(kind='hist', bins=20, title='Bad Apple Crunchiness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# #an apple becomes soft or mushy, it's a sign that something has affected its cell structure. Spoilage can occur

# %%
# @title Sweetness

from matplotlib import pyplot as plt
df_bad['Sweetness'].plot(kind='hist', bins=20, title='Bad Apple Sweetness')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_good.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1861 entries, 0 to 3785
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         1861 non-null   float64
#  1   Weight       1861 non-null   float64
#  2   Sweetness    1861 non-null   float64
#  3   Crunchiness  1861 non-null   float64
#  4   Juiciness    1861 non-null   float64
#  5   Ripeness     1861 non-null   float64
#  6   Acidity      1861 non-null   float64
#  7   Quality      1861 non-null   bool
# dtypes: bool(1), float64(7)
# memory usage: 118.1 KB

# %%
#finding EDA
sns.set()
sns.displot(df_good, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
plt.title(" Good Distribution Diagram")
# Out:
# <ipython-input-137-640e74d32601>:3: UserWarning:
# The palette list has fewer values (7) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.displot(df_good, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
# <ipython-input-137-640e74d32601>:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(df_good, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
# Text(0.5, 1.0, ' Good Distribution Diagram')

# %%
#finding EDA
sns.set()
sns.displot(df_bad, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
plt.title(" Bad Distribution Diagram")
plt.show()
# Out:
# <ipython-input-138-8face1816140>:3: UserWarning:
# The palette list has fewer values (7) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.displot(df_bad, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
# <ipython-input-138-8face1816140>:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(df_bad, kind= "kde", palette= custom_palette[:len(columns_list)-1], )

# %%
input_data = remove_outliers(input_data)

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3786 entries, 0 to 3785
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Size         3786 non-null   float64
#  1   Weight       3786 non-null   float64
#  2   Sweetness    3786 non-null   float64
#  3   Crunchiness  3786 non-null   float64
#  4   Juiciness    3786 non-null   float64
#  5   Ripeness     3786 non-null   float64
#  6   Acidity      3786 non-null   float64
#  7   Quality      3786 non-null   bool
# dtypes: bool(1), float64(7)
# memory usage: 210.9 KB

# %% [markdown]
# ### Creating a cleaned csv file for the dataset

# %%
input_data.to_csv(r"F:\Study\Datanest 4.0\My Work\cleaned_dataset.csv")

# %%
#CLEANING
plt.figure(figsize = (10, 6))
sns.boxplot(input_data, palette = custom_palette[:len(columns_list)], fill = False)
plt.title("Distribution of Attributes")

plt.show()

# %%
input_data.describe()
# Out:
#               Size       Weight    Sweetness  Crunchiness    Juiciness  \
# count  3786.000000  3786.000000  3786.000000  3786.000000  3786.000000
# mean     -0.510341    -0.986935    -0.478651     0.985697     0.500146
# std       1.850207     1.497316     1.871786     1.297315     1.849076
# min      -5.692093    -5.058679    -5.548641    -2.620954    -4.667150
# 25%      -1.796627    -1.967852    -1.724304     0.094724    -0.793372
# 50%      -0.514404    -0.979316    -0.504758     0.996911     0.509758
# 75%       0.769200     0.010353     0.777221     1.874618     1.786527
# max       4.524772     3.081538     4.606386     4.591936     5.598023
#
#           Ripeness      Acidity
# count  3786.000000  3786.000000
# mean      0.526871     0.059527
# std       1.800784     2.046333
# min      -4.471210    -5.634195
# 25%      -0.707739    -1.371829
# 50%       0.527629     0.014862
# 75%       1.768073     1.465006
# max       5.484760     5.685253

# %%
input_data.corr()
# Out:
#                  Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# Size         1.000000 -0.149304  -0.336310     0.171055  -0.022723 -0.156005
# Weight      -0.149304  1.000000  -0.140591    -0.094948  -0.088453 -0.228173
# Sweetness   -0.336310 -0.140591   1.000000    -0.025661   0.083961 -0.274354
# Crunchiness  0.171055 -0.094948  -0.025661     1.000000  -0.228927 -0.195303
# Juiciness   -0.022723 -0.088453   0.083961    -0.228927   1.000000 -0.102721
# Ripeness    -0.156005 -0.228173  -0.274354    -0.195303  -0.102721  1.000000
# Acidity      0.178790  0.040023   0.065574     0.073362   0.241848 -0.199820
# Quality      0.251724 -0.004932   0.246950    -0.002694   0.253436 -0.259032
#
#               Acidity   Quality
# Size         0.178790  0.251724
# Weight       0.040023 -0.004932
# Sweetness    0.065574  0.246950
# Crunchiness  0.073362 -0.002694
# Juiciness    0.241848  0.253436
# Ripeness    -0.199820 -0.259032
# Acidity      1.000000 -0.012774
# ...

# %%
# EDA
import numpy as np

output_data = input_data['Quality']
input_data.drop(['Quality'], axis=1, inplace = True)
corr_matrix = input_data.corr()
plt.figure(figsize=(20, 10))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_matrix, annot=True, cmap=cmap)
plt.title('Correlation Map for Numeric Variables')
plt.show()

# %%
#finding EDA
sns.displot(input_data, kind= "kde", palette= custom_palette[:len(columns_list)-1], )
plt.title("Attributes Distribution ")
plt.show()

# %%
input_data.isna().sum()
# Out:
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# dtype: int64

# %%
output_data.isna().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.2, random_state=100)

# %%
# Instantiate the KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)

# Model Training
knn.fit(X_train, y_train)

# Model Evaluation
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.895778364116095

# %%
classifier = KNeighborsClassifier()
classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Generate and print the classification report
report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.92      0.87      0.90       393
#         True       0.87      0.92      0.89       365
#
#     accuracy                           0.90       758
#    macro avg       0.90      0.90      0.90       758
# weighted avg       0.90      0.90      0.90       758

# %%
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
df_report = pd.DataFrame(report).transpose()

# Plotting the filled chart
plt.figure(figsize=(8, 6))
sns.heatmap(df_report.iloc[:-1, :-1], annot=True, cmap="Blues", fmt=".2f", linewidths=.5)
plt.title('Classification Report - KNN')
plt.show()

# %%
# Instantiate Random Forest classifier
random_forest = RandomForestClassifier(n_estimators=100, random_state=100)  # You can adjust the number of trees (n_estimators)

# Train the Random Forest classifier
random_forest.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = random_forest.predict(X_test)

# Evaluate the performance of Random Forest
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8852242744063324

# %%
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = classifier.predict(X_test)

# Generate and print the classification report
report = classification_report(y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.91      0.84      0.87       393
#         True       0.84      0.91      0.88       365
#
#     accuracy                           0.87       758
#    macro avg       0.88      0.88      0.87       758
# weighted avg       0.88      0.87      0.87       758

# %%
# Generate and print the classification report
report = classification_report(y_test, y_pred, output_dict=True)

# Convert the classification report to a DataFrame
df_report = pd.DataFrame(report).transpose()

# Plotting the filled chart
plt.figure(figsize=(8, 6))
sns.heatmap(df_report.iloc[:-1, :-1], annot=True, cmap="Blues", fmt=".2f", linewidths=.5)
plt.title('Classification Report - Random Forest')
plt.show()

# %%
df_good
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 3     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5     1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 6    -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# ...        ...       ...        ...          ...        ...       ...
# 3778  1.764253 -2.079695  -0.083383    -0.086724  -1.703385  3.840101
# 3780  1.482508 -2.581181  -0.306888     1.527877   1.056361  2.560829
# 3782 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3784 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3785  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.722809     True
# 2     0.790723     True
# 3     0.501984     True
# 5     2.414171     True
# ...

# %%
df_bad
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 1    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 4    -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 7    -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 8    -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
# 9    -2.699336 -1.329507  -1.418507    -0.625546   2.371074  3.403165
# ...        ...       ...        ...          ...        ...       ...
# 3775 -2.282625 -0.225517  -1.698524     0.936855  -1.385481  3.249894
# 3776 -1.396794 -0.599596  -1.931104     1.815668   1.670732  1.614027
# 3779  1.520142 -0.352623  -3.206467     1.341719   0.675568  0.107093
# 3781  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3783 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
#
#        Acidity  Quality
# 1     2.621636    False
# 4    -2.981523    False
# 7    -4.871905    False
# 8     2.185608    False
# ...

# %%
from scipy.stats import norm

def calculate_p_value(confidence_interval):
    # Assuming a two-tailed test
    alpha = 1 - confidence_interval
    z_score = norm.ppf(1 - alpha / 2)

    # Calculate p-value
    p_value = 2 * (1 - norm.cdf(z_score))

    return p_value

# Example: 95% confidence interval
confidence_interval = 0.95
p_value_95 = calculate_p_value(confidence_interval)

print(f'P-value for a {confidence_interval * 100}% confidence interval: {p_value_95}')
# Out:
# P-value for a 95.0% confidence interval: 0.050000000000000044

# %%
from scipy import stats

# Example data (replace with your actual data)
data1 = df_good['Weight']
data2 = df_bad['Weight']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")
# Out:
# Statistic: 134.42096955594548
# P-Value: 1.4435582988966695e-30
# The variances are significantly different.

# %%
# apple weight
from scipy import stats

# Example data (replace with your actual data)
data1 = df_good['Weight']
data2 = df_bad['Weight']

# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# T-Statistic: -0.30340650029463634
# P-Value: 0.7615967723985629
# There is no significant difference between the groups.

# %%
# size
# Example data (replace with your actual data)
data1 = df_good['Size']
data2 = df_bad['Size']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 17.100224779999706
# P-Value: 3.622766969220017e-05
# The variances are significantly different.
# T-Statistic: 15.999833087306195
# P-Value: 8.344658745123348e-56
# The difference between the groups is statistically significant.

# %%
# Sweetness
# Example data (replace with your actual data)
data1 = df_good['Sweetness']
data2 = df_bad['Sweetness']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2,equal_var = True)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 1.3387843139465339
# P-Value: 0.24732150558849028
# There is no significant difference in variances.
# T-Statistic: 15.67648359985584
# P-Value: 1.036340945200862e-53
# The difference between the groups is statistically significant.

# %%
#Crunchinesss
# Example data (replace with your actual data)
data1 = df_good['Crunchiness']
data2 = df_bad['Crunchiness']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 127.34562184111857
# P-Value: 4.5252030690882015e-29
# The variances are significantly different.
# T-Statistic: -0.16573096927961997
# P-Value: 0.8683775267449635
# There is no significant difference between the groups.

# %%
#Juiciness

# Example data (replace with your actual data)
data1 = df_good['Juiciness']
data2 = df_bad['Juiciness']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 61.7190253148086
# P-Value: 5.1221684299922925e-15
# The variances are significantly different.
# T-Statistic: 16.116063877428868
# P-Value: 1.4441858559224924e-56
# The difference between the groups is statistically significant.

# %%
# Ripeness
# Example data (replace with your actual data)
data1 = df_good['Ripeness']
data2 = df_bad['Ripeness']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 9.22278613072154
# P-Value: 0.00240650928198578
# The variances are significantly different.
# T-Statistic: -16.4972301816452
# P-Value: 4.24708369007731e-59
# The difference between the groups is statistically significant.

# %%
#Acidity

# Example data (replace with your actual data)
data1 = df_good['Acidity']
data2 = df_bad['Acidity']

# Perform Levene's test for equality of variances
statistic, p_value = stats.levene(data1, data2)

# Display the results
print(f'Statistic: {statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The variances are significantly different.")
else:
    print("There is no significant difference in variances.")


# Perform independent two-sample t-test
t_statistic, p_value = stats.ttest_ind(data1, data2)

# Display the results
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')

# Check the significance level (commonly 0.05)
alpha = 0.05
if p_value < alpha:
    print("The difference between the groups is statistically significant.")
else:
    print("There is no significant difference between the groups.")
# Out:
# Statistic: 16.39086175011933
# P-Value: 5.2564439129562405e-05
# The variances are significantly different.
# T-Statistic: -0.7858467145444777
# P-Value: 0.43200649916742306
# There is no significant difference between the groups.

# %% [markdown]
# #apple size
# Statistic: 17.100224779999706
# P-Value: 3.622766969220017e-05
# The variances are significantly different.
# T-Statistic: 15.999833087306195
# P-Value: 8.344658745123348e-56
# The difference between the groups is statistically significant.
#
# #Sweetness
# Statistic: 1.3387843139465339
# P-Value: 0.24732150558849028
# There is no significant difference in variances.
# T-Statistic: 15.67648359985584
# P-Value: 1.036340945200862e-53
# The difference between the groups is statistically significant
# #Crunchinesss
# Statistic: 127.34562184111857
# P-Value: 4.5252030690882015e-29
# The variances are significantly different.
# T-Statistic: -0.16573096927961997
# P-Value: 0.8683775267449635
# There is no significant difference between the groups
# #Juiciness
# Statistic: 61.7190253148086
# P-Value: 5.1221684299922925e-15
# The variances are significantly different.
# T-Statistic: 16.116063877428868
# P-Value: 1.4441858559224924e-56
# The difference between the groups is statistically significant
# #Ripness
# tatistic: 9.22278613072154
# P-Value: 0.00240650928198578
# The variances are significantly different.
# T-Statistic: -16.4972301816452
# P-Value: 4.24708369007731e-59
# The difference between the groups is statistically significant
# #Acidity
# tatistic: 16.39086175011933
# P-Value: 5.2564439129562405e-05
# The variances are significantly different.
# T-Statistic: -0.7858467145444777
# P-Value: 0.43200649916742306
# There is no significant difference between the group

# %% [markdown]
# ###Market Insights from Apple Quality Analysis
# #Overall Analysis:
# Significant Differences: Apple size, sweetness, juiciness, and ripeness exhibit substantial differences between the two groups.
# Consistent Attributes: Crunchiness and acidity show no significant differences, indicating consistent quality attributes.
# #Strategic Considerations:
# Marketing Emphasis: Highlight unique features such as size, sweetness, and juiciness to appeal to consumer preferences.
# Quality Control: Focus on maintaining consistent crunchiness and acidity levels for overall product reliability.
# Market Positioning: Leverage significant differences in attributes for targeted market positioning and consumer segmentation.
